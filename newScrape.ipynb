# %% [markdown]
# # Assessment 1.1: Web Scraping
# ## By Daniel Thompson
# ## Studnet ID: 110382831
# ## Email: thody038@mymail.unisa.edu.au

# %% [markdown]
# ### Web Scraping
#
# The following Python code performs web scraping from Wikipedia to extract information about the 2023 AFL season.

# %%
import re
import requests
from bs4 import BeautifulSoup
import csv

# %%
# Initialise list of URLs
urls = []
# Opens inputs.txt and reads line by line and adds to list of urls
text_filename = "inputs.txt"
with open(text_filename, 'r') as file:
    urls = [line.strip() for line in file.readlines() if line.strip()]

# %%
# Function to extract rounds, returned as a ResultSet
def extract_rounds(soup):
    
    # Find all elements with a span tag whose id attribute starts with "Round_"
    round_numbers = soup.find_all('span', id=lambda x: x and x.startswith("Round_"))

    return round_numbers

# Function to extract day from text
def extract_day(text_row):
    day_pattern = r'^.*day'
    regex = re.compile(day_pattern)
    match = regex.search(text_row)
    return match.group() if match else None

# Function to extract date from text
def extract_date(text_row):
    date_pattern = r'[0-9]{1,2} [A-Z]{1}[a-z]+'
    regex = re.compile(date_pattern)
    match = regex.search(text_row)
    return match.group() if match else None

# Function to extract time from text
def extract_time(text_row):
    time_pattern = r'[0-9]{1,2}:[0-9]{2}\s[apmAPM]{2}'
    regex = re.compile(time_pattern)
    match = regex.search(text_row)
    return match.group() if match else None

# Function to extract the home team from a table cell element
def extract_home_team(td_element): 
    if td_element.get('align') == 'right':  
        team_pattern = r'[A-Za-z]+(?:\s[A-Za-z]+){0,2}\s'
        regex = re.compile(team_pattern)
        match = regex.search(td_element.text)
        return match.group() if match else None
    else:
        return None

# Function to extract the home score from a table cell element    
def extract_home_score(td_element):
    if td_element.get('align') == 'right':
        score_pattern = r'[0-9]{1,3}\.[0-9]{1,3}\s\([0-9]{1,3}\)'
        regex = re.compile(score_pattern)
        match = regex.search(td_element.text)
        return match.group() if match else None
    else:
        return None
    
# Function to extract the match result from a table cell element ("def by","def", "drew with")
def extract_result(td_element):
    if td_element.get('style') == 'text-align:center;':
       return td_element.text.strip()
    else:
        return None
    
# Function to extract the away team from a table cell element
def extract_away_team(td_element):
    if not td_element.has_attr('align') and not td_element.get('style') == 'font-size: 85%' and not td_element.get('colspan') == '6' and not td_element.get('colspan') == '3':
        anchor_elements = td_element.find('a')
        if anchor_elements:
            team_pattern = r'[A-Za-z]+(?:\s[A-Za-z]+){0,2}\s'
            regex = re.compile(team_pattern)
            match = regex.search(td_element.text)
            return match.group() if match else None
    else:
        return None

# Function to extract the away score from a table cell element    
def extract_away_score(td_element):
    if not td_element.has_attr('align') and not td_element.get('style') == 'font-size: 85%':
        anchor_elements = td_element.find('a')
        if anchor_elements:
            score_pattern = r'[0-9]{1,3}\.[0-9]{1,3}\s\([0-9]{1,3}\)'
            regex = re.compile(score_pattern)
            match = regex.search(td_element.text)
            return match.group() if match else None
    else:
        return None

# Function to extract the venue from a table cell element    
def extract_venue(td_element):
    if td_element.get('style') == 'font-size: 85%':
        anchor_elements = td_element.find('a')
        if anchor_elements:
            venue_pattern = r'([A-Za-z]+(?:\s[A-Za-z]+){0,2})\s'
            regex = re.compile(venue_pattern)
            match = regex.search(td_element.text)
            if match.group() != "ReportStats\n":
                return match.group() if match else None
    else:
        return None

# Function to extract the attendance from a table cell element
def extract_attendance(td_element):
    if td_element.get('style') == 'font-size: 85%':
        attendance_pattern = r'([0-9]{1,3},[0-9]{3})'
        regex = re.compile(attendance_pattern)
        match = regex.search(td_element.text)
        return match.group() if match else None
    else:
        return None

# %%
   
def data_extraction(round_numbers):


    # Iterate through each round in the list of round numbers
    for round in round_numbers:
        try:
            # Extract the text of the round, which contains the round name
            round_name = round.text
            print(round_name)

            # Find the next table after the current round element
            table = round.find_next('table')

            # Iterate through each row in the table extracting the details of each match. Print each one if they return anything not None
            for row in table.find_all('td'):
                try:
                    day = extract_day(row.text)
                    if day:
                        print(day, end=',')
                    date = extract_date(row.text)
                    if date:
                        print(date, end=',')
                    time = extract_time(row.text)
                    if time:
                        print(time, end=',')
                    home_team = extract_home_team(row)
                    if home_team:
                        print(home_team, end=',')
                    home_score = extract_home_score(row)
                    if home_score:
                        print(home_score, end=',')
                    result = extract_result(row)
                    if result:
                        print(result, end=',')
                    away_team = extract_away_team(row)
                    if away_team:
                        print(away_team, end=',')
                    away_score = extract_away_score(row)
                    if away_score:
                        print(away_score, end=',')
                    venue = extract_venue(row)
                    if venue:
                        print(venue, end=',')
                    attendance = extract_attendance(row)
                    if attendance:
                        print(attendance)
                except Exception as e:
                    print(f"Error processing row: {e}")
        except Exception as e:
            print(f"Error processing round: {e}")

# %%
def write_to_csv(round_numbers, count):
    # Define the filename for the CSV file
    csv_filename = "extracted_data.csv"
    day, date, time, home_team, home_score, result, away_team, away_score, venue, attendance = None, None, None, None, None, None, None, None, None, None

    # Default appends
    mode = 'a'
    
    # If first time calling function, mode will change to 'write'
    if count == 0:
        mode = 'w'

    # Open the CSV file in write mode
    try:
        with open(csv_filename, mode, newline='') as file:
            # Create a CSV writer object
            csv_writer = csv.writer(file)

            # Write header rows for men's data
            # csv_writer.writerow(["Men's"])
            csv_writer.writerow(["Round", "Day", "Date", "Time", "Home Team", "Home Score", "Result", "Away Team", "Away Score", "Venue", "Attendance"])

            # Iterate through each round in the list of round numbers
            for round in round_numbers:
                try:
                    round_name = round.text
                    table = round.find_next('table')
                    
                    for row in table.find_all('td'):
                        try:
                            # Extract data for each field if it hasn't been extracted yet    
                            if day is None:
                                day = extract_day(row.text)
                            if date is None:
                                date = extract_date(row.text)
                            if time is None:
                                time = extract_time(row.text)
                            if home_team is None:
                                home_team = extract_home_team(row)
                            if home_score is None:
                                home_score = extract_home_score(row)
                            if result is None:
                                result = extract_result(row)
                            if away_team is None:
                                away_team = extract_away_team(row)
                            if away_score is None:
                                away_score = extract_away_score(row)
                            if venue is None:
                                venue = extract_venue(row)
                            if attendance is None:
                                attendance = extract_attendance(row)

                            # Check if all fields have been extracted    
                            if all(field is not None for field in [day, date, time, home_team, home_score, result, away_team, away_score, venue, attendance]):
                                # Write the extracted data to the CSV file
                                csv_writer.writerow([round_name, day, date, time, home_team, home_score, result, away_team, away_score, venue, attendance])
                                # Reset variables for the next row
                                day, date, time, home_team, home_score, result, away_team, away_score, venue, attendance = None, None, None, None, None, None, None, None, None, None
                        except Exception as e:
                            print(f"Error processing row: {e}")
                except Exception as e:
                    print(f"Error processing round: {e}")
    except Exception as e:
        print(f"Error writing to CSV file: {e}")

# %%
# Count initialised to track number of times write_to_csv() has been called to determine whether it writes or appends to the csv
count = 0

# Iterates throught the list of URLs
for url in urls:

    try:
        # Send a GET request to the URL
        response = requests.get(url)
        
        # Check status for good connection
        if response.status_code == 200:
            print("Connection successful")
        else:
            print(f"Failed to connect. Status code: {response.status_code}")

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Calls to collect the ResultSet of rounds to iterate in the following functions
        round_numbers = extract_rounds(soup)

        # Calls to print data as a confidence check that the information is being extracted correctly
        data_extraction(round_numbers)
        # If count == 0, writes to CSV, else appends to CSV
        write_to_csv(round_numbers, count)
        count += 1

            
    except requests.RequestException as e:
        print(f"Error during request: {e}")
# Out:
# Connection successful
# Round 1
# Thursday,16 March,7:20 pm,Richmond ,8.10 (58),drew with,Carlton ,8.10 (58),Melbourne Cricket Ground ,88,084
# Friday,17 March,7:40 pm,Geelong ,16.7 (103),def. by,Collingwood ,19.11 (125),Melbourne Cricket Ground ,86,595
# Saturday,18 March,1:45 pm,North Melbourne ,12.15 (87),def.,West Coast ,12.10 (82),Marvel Stadium ,21,274
# Saturday,18 March,4:05 pm,Port Adelaide ,18.18 (126),def.,Brisbane Lions ,11.6 (72),Adelaide Oval ,34,255
# Saturday,18 March,7:25 pm,Melbourne ,17.13 (115),def.,Western Bulldogs ,9.11 (65),Melbourne Cricket Ground ,48,103
# Saturday,18 March,7:00 pm,Gold Coast ,9.7 (61),def. by,Sydney ,16.14 (110),Heritage Bank Stadium ,13,648
# Sunday,19 March,1:10 pm,Greater Western Sydney ,15.16 (106),def.,Adelaide ,12.18 (90),Giants Stadium ,8,169
# Sunday,19 March,3:20 pm,Hawthorn ,9.11 (65),def. by,Essendon ,19.10 (124),Melbourne Cricket Ground ,68,691
# Sunday,19 March,4:40 pm,St Kilda ,10.7 (67),def.,Fremantle ,7.10 (52),Marvel Stadium ,23,429
# Round 2
# Thursday,23 March,7:20 pm,Carlton ,13.12 (90),def.,Geelong ,12.10 (82),Melbourne Cricket Ground ,55,861
# Friday,24 March,6:55 pm,Brisbane Lions ,14.9 (93),def.,Melbourne ,13.4 (82),The Gabba ,30,047
# Saturday,25 March,1:45 pm,Collingwood ,21.9 (135),def.,Port Adelaide ,9.10 (64),Melbourne Cricket Ground ,60,744
# Saturday,25 March,4:05 pm,Adelaide ,10.16 (76),def. by,Richmond ,17.6 (108),Adelaide Oval ,38,492
# Saturday,25 March,7:25 pm,Western Bulldogs ,5.11 (41),def. by,St Kilda ,14.8 (92),Marvel Stadium ,33,294
# Saturday,25 March,4:30 pm,Fremantle ,10.12 (72),def. by,North Melbourne ,11.7 (73),Optus Stadium ,40,487
# Sunday,26 March,1:10 pm,Sydney ,17.16 (118),def.,Hawthorn ,4.13 (37),Sydney Cricket Ground ,37,052
# Sunday,26 March,3:20 pm,Essendon ,16.12 (108),def.,Gold Coast ,11.14 (80),Marvel Stadium ,32,915
# Sunday,26 March,3:20 pm,West Coast ,14.16 (100),def.,Greater Western Sydney ,11.15 (81),Optus Stadium ,44,649
# Round 3
# Thursday,30 March,7:20 pm,Western Bulldogs ,10.7 (67),def.,Brisbane Lions ,7.11 (53),Marvel Stadium ,23,665
# Friday,31 March,7:50 pm,Collingwood ,8.15 (63),def.,Richmond ,7.7 (49),Melbourne Cricket Ground ,85,241
# Saturday,1 April,1:45 pm,Hawthorn ,11.14 (80),def.,North Melbourne ,9.7 (61),University of Tasmania ,11,007
# Saturday,1 April,4:35 pm,Greater Western Sydney ,9.10 (64),def. by,Carlton ,9.20 (74),Giants Stadium ,9,691
# Saturday,1 April,7:25 pm,St Kilda ,14.8 (92),def.,Essendon ,11.8 (74),Melbourne Cricket Ground ,69,255
# Saturday,1 April,7:30 pm,Port Adelaide ,13.8 (86),def. by,Adelaide ,18.9 (117),Adelaide Oval ,48,962
# Sunday,2 April,2:10 pm,Gold Coast ,10.13 (73),def.,Geelong ,7.12 (54),Heritage Bank Stadium ,13,122
# Sunday,2 April,3:20 pm,Melbourne ,21.8 (134),def.,Sydney ,12.12 (84),Melbourne Cricket Ground ,42,423
# Sunday,2 April,3:20 pm,Fremantle ,16.12 (108),def.,West Coast ,9.13 (67),Optus Stadium ,56,090
# Round 4
# Thursday,6 April,7:35 pm,Brisbane Lions ,18.8 (116),def.,Collingwood ,11.17 (83),The Gabba ,33,565
# Friday,7 April,4:20 pm,North Melbourne ,11.18 (84),def. by,Carlton ,16.11 (107),Marvel Stadium ,49,062
# Saturday,8 April,1:15 pm,Adelaide ,17.9 (111),def.,Fremantle ,10.12 (72),Adelaide Oval ,33,725
# Saturday,8 April,4:35 pm,Richmond ,12.12 (84),def. by,Western Bulldogs ,12.17 (89),Melbourne Cricket Ground ,56,449
# Saturday,8 April,7:30 pm,Sydney ,9.10 (64),def. by,Port Adelaide ,9.12 (66),Sydney Cricket Ground ,31,686
# Saturday,8 April,7:30 pm,St Kilda ,17.11 (113),def.,Gold Coast ,8.12 (60),Marvel Stadium ,21,049
# Sunday,9 April,2:10 pm,Essendon ,11.22 (88),def.,Greater Western Sydney ,11.9 (75),Marvel Stadium ,28,815
# Sunday,9 April,3:20 pm,West Coast ,9.9 (63),def. by,Melbourne ,19.12 (126),Optus Stadium ,42,458
# Monday,10 April,3:20 pm,Geelong ,19.13 (127),def.,Hawthorn ,6.9 (45),Melbourne Cricket Ground ,65,335
# Round 5
# Thursday,13 April,7:10 pm,Adelaide ,18.10 (118),def.,Carlton ,9.8 (62),Adelaide Oval ,47,395
# Friday,14 April,4:40 pm,Gold Coast ,13.12 (90),def. by,Fremantle ,15.10 (100),Norwood Oval ,9,329
# Friday,14 April,7:40 pm,Sydney ,18.14 (122),def.,Richmond ,11.12 (78),Adelaide Oval ,42,134
# Saturday,15 April,12:40 pm,North Melbourne ,12.5 (77),def. by,Brisbane Lions ,22.20 (152),7,329
# Saturday,15 April,3:40 pm,Melbourne ,11.11 (77),def. by,Essendon ,15.14 (104),Adelaide Oval ,33,832
# Saturday,15 April,7:20 pm,Port Adelaide ,10.10 (70),def.,Western Bulldogs ,8.8 (56),Adelaide Oval ,45,115
# Sunday,16 April,12:40 pm,West Coast ,13.11 (89),def. by,Geelong ,21.10 (136),Adelaide Oval ,30,120
# Sunday,16 April,2:50 pm,Greater Western Sydney ,10.17 (77),def.,Hawthorn ,11.9 (75),Norwood Oval ,9,057
# Sunday,16 April,4:20 pm,St Kilda ,9.10 (64),def. by,Collingwood ,10.10 (70),Adelaide Oval ,43,976
# Round 6
# Friday,21 April,6:10 pm,Fremantle ,10.9 (69),def. by,Western Bulldogs ,17.16 (118),Optus Stadium ,47,503
# Saturday,22 April,1:15 pm,Port Adelaide ,16.13 (109),def.,West Coast ,10.9 (69),Adelaide Oval ,31,638
# Saturday,22 April,4:35 pm,Greater Western Sydney ,13.9 (87),def. by,Brisbane Lions ,16.12 (108),Manuka Oval ,10,461
# Saturday,22 April,7:25 pm,Geelong ,20.10 (130),def.,Sydney ,5.7 (37),GMHBA Stadium ,23,134
# Sunday,23 April,1:10 pm,Hawthorn ,11.10 (76),def. by,Adelaide ,11.13 (79),University of Tasmania ,10,119
# Sunday,23 April,3:20 pm,Carlton ,8.12 (60),def. by,St Kilda ,12.10 (82),Marvel Stadium ,45,770
# Sunday,23 April,4:40 pm,Gold Coast ,14.13 (97),def.,North Melbourne ,7.12 (54),Heritage Bank Stadium ,9,672
# Monday,24 April,7:25 pm,Melbourne ,15.6 (96),def.,Richmond ,11.12 (78),Melbourne Cricket Ground ,83,985
# Tuesday,25 April,3:20 pm,Collingwood ,13.12 (90),def.,Essendon ,11.11 (77),Melbourne Cricket Ground ,95,179
# 0.3 (3),Round 7
# Friday,28 April,7:50 pm,St Kilda ,11.10 (76),def. by,Port Adelaide ,12.11 (83),Marvel Stadium ,25,845
# Saturday,29 April,1:45 pm,Brisbane Lions ,17.13 (115),def.,Fremantle ,10.7 (67),The Gabba ,25,528
# Saturday,29 April,2:10 pm,Sydney ,16.10 (106),def. by,Greater Western Sydney ,17.5 (107),Sydney Cricket Ground ,31,615
# Saturday,29 April,4:35 pm,Western Bulldogs ,14.10 (94),def.,Hawthorn ,9.11 (65),Marvel Stadium ,40,119
# Saturday,29 April,7:25 pm,Melbourne ,22.7 (139),def.,North Melbourne ,7.7 (49),Melbourne Cricket Ground ,29,455
# Saturday,29 April,5:30 pm,West Coast ,6.8 (44),def. by,Carlton ,23.14 (152),Optus Stadium ,47,940
# Sunday,30 April,1:10 pm,Essendon ,16.8 (104),def. by,Geelong ,20.12 (132),Melbourne Cricket Ground ,67,457
# Sunday,30 April,3:20 pm,Richmond ,6.12 (48),def. by,Gold Coast ,11.6 (72),Marvel Stadium ,23,664
# Sunday,30 April,4:10 pm,Adelaide ,7.16 (58),def. by,Collingwood ,8.11 (59),Adelaide Oval ,43,942
# Round 8
# Friday,5 May,7:50 pm,Carlton ,11.8 (74),def. by,Brisbane Lions ,15.10 (100),Marvel Stadium ,45,458
# Saturday,6 May,1:45 pm,Richmond ,15.14 (104),def.,West Coast ,8.10 (58),Melbourne Cricket Ground ,28,293
# Saturday,6 May,2:10 pm,Geelong ,14.14 (98),def.,Adelaide ,11.6 (72),GMHBA Stadium ,21,415
# Saturday,6 May,4:35 pm,Gold Coast ,13.7 (85),def. by,Melbourne ,13.12 (90),Heritage Bank Stadium ,11,440
# Saturday,6 May,7:30 pm,Greater Western Sydney ,10.11 (71),def. by,Western Bulldogs ,13.8 (86),Manuka Oval ,10,039
# Saturday,6 May,5:30 pm,Fremantle ,18.9 (117),def.,Hawthorn ,7.6 (48),Optus Stadium ,37,160
# Sunday,7 May,12:40 pm,Port Adelaide ,12.20 (92),def.,Essendon ,13.9 (87),Adelaide Oval ,36,247
# Sunday,7 May,3:20 pm,Collingwood ,11.11 (77),def.,Sydney ,6.12 (48),Melbourne Cricket Ground ,71,463
# Sunday,7 May,4:40 pm,North Melbourne ,4.10 (34),def. by,St Kilda ,8.16 (64),Marvel Stadium ,22,065
# 0.7 (7),Round 9
# Friday,12 May,7:20 pm,Richmond ,16.6 (102),def.,Geelong ,11.12 (78),Melbourne Cricket Ground ,58,141
# Friday,12 May,6:40 pm,West Coast ,6.7 (43),def. by,Gold Coast ,16.17 (113),Optus Stadium ,36,219
# Saturday,13 May,1:45 pm,Sydney ,13.8 (86),def. by,Fremantle ,16.7 (103),Sydney Cricket Ground ,28,927
# Saturday,13 May,2:10 pm,North Melbourne ,10.5 (65),def. by,Port Adelaide ,20.15 (135),Blundstone Arena ,6,310
# Saturday,13 May,4:35 pm,Hawthorn ,7.7 (49),def. by,Melbourne ,15.13 (103),Melbourne Cricket Ground ,39,818
# Saturday,13 May,7:25 pm,Brisbane Lions ,12.15 (87),def.,Essendon ,6.9 (45),The Gabba ,31,898
# Saturday,13 May,7:30 pm,Carlton ,8.11 (59),def. by,Western Bulldogs ,11.13 (79),Marvel Stadium ,42,756
# Sunday,14 May,12:40 pm,Adelaide ,19.7 (121),def.,St Kilda ,10.9 (69),Adelaide Oval ,33,805
# Sunday,14 May,4:40 pm,Collingwood ,18.12 (120),def.,Greater Western Sydney ,7.13 (55),Melbourne Cricket Ground ,37,631
# Round 10
# Friday,19 May,7:20 pm,Yartapuulti ,11.14 (80),def.,Narrm ,11.10 (76),Adelaide Oval ,37,565
# Saturday,20 May,1:45 pm,North Melbourne ,14.6 (90),def. by,Sydney ,14.9 (93),Marvel Stadium ,21,003
# Saturday,20 May,2:10 pm,Western Bulldogs ,11.19 (85),def.,Adelaide ,5.10 (40),Mars Stadium ,10,114
# Saturday,20 May,2:35 pm,Walyalup ,16.10 (106),def.,Geelong ,11.11 (77),Optus Stadium ,45,811
# Saturday,20 May,7:30 pm,Brisbane Lions ,16.11 (107),def.,Gold Coast ,9.10 (64),The Gabba ,23,286
# Saturday,20 May,7:40 pm,Essendon ,10.11 (71),def.,Richmond ,10.10 (70),Melbourne Cricket Ground ,78,300
# Sunday,21 May,1:10 pm,Hawthorn ,22.10 (142),def.,West Coast ,4.2 (26),University of Tasmania ,9,135
# Sunday,21 May,3:20 pm,Carlton ,7.15 (57),def. by,Collingwood ,13.7 (85),Melbourne Cricket Ground ,80,354
# Sunday,21 May,4:40 pm,Greater Western Sydney ,12.8 (80),def. by,St Kilda ,13.14 (92),Giants Stadium ,7,508
# 4.2 (26),Round 11
# Friday,26 May,7:50 pm,Sydney ,11.11 (77),def.,Carlton ,6.15 (51),Sydney Cricket Ground ,36,310
# Saturday,27 May,1:45 pm,St Kilda ,12.6 (78),def. by,Hawthorn ,12.16 (88),Marvel Stadium ,32,022
# Saturday,27 May,2:10 pm,Narrm ,10.12 (72),def. by,Walyalup ,12.7 (79),Melbourne Cricket Ground ,29,154
# Saturday,27 May,4:35 pm,Geelong ,10.14 (74),def. by,Greater Western Sydney ,12.9 (81),GMHBA Stadium ,21,349
# Saturday,27 May,6:55 pm,Gold Coast ,13.6 (84),def.,Western Bulldogs ,11.11 (77),TIO Stadium ,9,316
# Saturday,27 May,5:40 pm,West Coast ,6.10 (46),def. by,Essendon ,14.12 (96),Optus Stadium ,39,269
# Sunday,28 May,1:10 pm,Richmond ,9.13 (67),def. by,Yartapuulti ,10.17 (77),Melbourne Cricket Ground ,30,357
# Sunday,28 May,3:20 pm,Collingwood ,16.9 (105),def.,North Melbourne ,10.10 (70),Marvel Stadium ,39,467
# Sunday,28 May,4:10 pm,Adelaide ,14.11 (95),def.,Brisbane Lions ,10.18 (78),Adelaide Oval ,33,188
# Round 12
# Friday,2 June,7:50 pm,Melbourne ,8.13 (61),def.,Carlton ,6.8 (44),Melbourne Cricket Ground ,49,872
# Saturday,3 June,1:15 pm,Port Adelaide ,23.13 (151),def.,Hawthorn ,14.12 (96),Adelaide Oval ,34,234
# Saturday,3 June,2:35 pm,West Coast ,8.9 (57),def. by,Collingwood ,18.12 (120),Optus Stadium ,41,713
# Saturday,3 June,7:25 pm,Western Bulldogs ,10.15 (75),def. by,Geelong ,15.7 (97),Marvel Stadium ,41,944
# Saturday,3 June,7:00 pm,Gold Coast ,16.16 (112),def.,Adelaide ,13.9 (87),TIO Stadium ,10,772
# Sunday,4 June,1:10 pm,Greater Western Sydney ,15.14 (104),def. by,Richmond ,16.14 (110),Giants Stadium ,9,723
# Sunday,4 June,4:40 pm,Essendon ,16.9 (105),def.,North Melbourne ,15.9 (99),Marvel Stadium ,40,488
# 16.9 (105),Round 13
# Thursday,8 June,7:10 pm,Sydney ,9.12 (66),def. by,St Kilda ,12.8 (80),Sydney Cricket Ground ,30,123
# Friday,9 June,7:50 pm,Western Bulldogs ,13.7 (85),def. by,Port Adelaide ,16.11 (107),Marvel Stadium ,23,110
# Saturday,10 June,1:45 pm,Hawthorn ,15.8 (98),def.,Brisbane Lions ,11.7 (73),Melbourne Cricket Ground ,35,869
# Saturday,10 June,4:05 pm,Adelaide ,27.12 (174),def.,West Coast ,8.4 (52),Adelaide Oval ,39,450
# Saturday,10 June,5:25 pm,Fremantle ,10.10 (70),def. by,Richmond ,12.13 (85),Optus Stadium ,46,843
# Sunday,11 June,3:20 pm,North Melbourne ,11.9 (75),def. by,Greater Western Sydney ,15.13 (103),Blundstone Arena ,5,025
# Sunday,11 June,7:15 pm,Carlton ,6.16 (52),def. by,Essendon ,13.8 (86),Melbourne Cricket Ground ,83,638
# Monday,12 June,3:20 pm,Melbourne ,8.18 (66),def.,Collingwood ,9.8 (62),Melbourne Cricket Ground ,83,578
# 1.1 (7),Round 14
# Thursday,15 June,7:10 pm,Port Adelaide ,16.14 (110),def.,Geelong ,11.6 (72),Adelaide Oval ,36,316
# Friday,16 June,7:50 pm,Brisbane Lions ,13.19 (97),def.,Sydney ,12.9 (81),The Gabba ,28,561
# Saturday,17 June,4:35 pm,Greater Western Sydney ,16.10 (106),def.,Fremantle ,5.6 (36),Giants Stadium ,8,633
# Saturday,17 June,7:25 pm,Richmond ,13.12 (90),def.,St Kilda ,11.4 (70),Melbourne Cricket Ground ,62,686
# Sunday,18 June,1:10 pm,Carlton ,18.12 (120),def.,Gold Coast ,8.13 (61),Melbourne Cricket Ground ,29,602
# Sunday,18 June,4:40 pm,North Melbourne ,13.6 (84),def. by,Western Bulldogs ,15.15 (105),Marvel Stadium ,23,829
# Round 15
# Thursday,22 June,7:20 pm,Geelong ,11.12 (78),def.,Melbourne ,8.15 (63),GMHBA Stadium ,19,617
# Friday,23 June,7:50 pm,St Kilda ,8.8 (56),def. by,Brisbane Lions ,12.12 (84),Marvel Stadium ,28,985
# Saturday,24 June,4:35 pm,Sydney ,31.19 (205),def.,West Coast ,5.4 (34),Sydney Cricket Ground ,31,367
# Saturday,24 June,5:30 pm,Fremantle ,14.9 (93),def.,Essendon ,9.7 (61),Optus Stadium ,43,063
# Sunday,25 June,1:10 pm,Collingwood ,12.10 (82),def.,Adelaide ,11.14 (80),Melbourne Cricket Ground ,65,930
# Sunday,25 June,4:40 pm,Gold Coast ,14.17 (101),def.,Hawthorn ,5.4 (34),Heritage Bank Stadium ,14,242
# 31.19 (205),Round 16
# Thursday,29 June,7:20 pm,Brisbane Lions ,20.14 (134),def.,Richmond ,7.11 (53),The Gabba ,30,022
# Friday,30 June,7:50 pm,Sydney ,6.18 (54),drew with,Geelong ,7.12 (54),Sydney Cricket Ground ,32,098
# Saturday,1 July,1:15 pm,Adelaide ,21.12 (138),def.,North Melbourne ,11.6 (72),Adelaide Oval ,35,226
# Saturday,1 July,1:45 pm,Western Bulldogs ,16.6 (102),def.,Fremantle ,11.7 (73),Marvel Stadium ,25,412
# Saturday,1 July,4:35 pm,Gold Coast ,5.12 (42),def. by,Collingwood ,18.12 (120),Heritage Bank Stadium ,22,483
# Saturday,1 July,7:25 pm,Essendon ,10.14 (74),def. by,Port Adelaide ,11.12 (78),Melbourne Cricket Ground ,38,957
# Sunday,2 July,1:10 pm,Hawthorn ,7.10 (52),def. by,Carlton ,17.10 (112),Melbourne Cricket Ground ,66,337
# Sunday,2 July,2:50 pm,Melbourne ,5.15 (45),def. by,Greater Western Sydney ,7.5 (47),TIO Traeger Park ,3,413
# Sunday,2 July,2:40 pm,West Coast ,12.5 (77),def. by,St Kilda ,12.13 (85),Optus Stadium ,35,579
# 0.5 (5),Round 17
# Thursday,6 July,7:20 pm,Richmond ,12.16 (88),def.,Sydney ,11.9 (75),Melbourne Cricket Ground ,48,443
# Friday,7 July,7:50 pm,Western Bulldogs ,11.11 (77),def. by,Collingwood ,13.11 (89),Marvel Stadium ,43,482
# Saturday,8 July,1:45 pm,Brisbane Lions ,16.20 (116),def.,West Coast ,5.5 (35),The Gabba ,24,843
# Saturday,8 July,4:35 pm,Greater Western Sydney ,12.13 (85),def.,Hawthorn ,10.12 (72),Giants Stadium ,9,007
# Saturday,8 July,7:25 pm,St Kilda ,8.10 (58),def. by,Melbourne ,12.7 (79),Marvel Stadium ,30,749
# Saturday,8 July,7:10 pm,Port Adelaide ,16.10 (106),def.,Gold Coast ,11.7 (73),Adelaide Oval ,31,053
# Sunday,9 July,1:10 pm,Geelong ,19.11 (125),def.,North Melbourne ,9.9 (63),GMHBA Stadium ,21,066
# Sunday,9 July,3:20 pm,Essendon ,17.13 (115),def.,Adelaide ,15.9 (97),Marvel Stadium ,39,606
# Sunday,9 July,2:40 pm,Fremantle ,6.9 (45),def. by,Carlton ,14.14 (98),Optus Stadium ,49,469
# Round 18
# Thursday,13 July,7:20 pm,Sydney ,11.12 (78),def.,Western Bulldogs ,11.10 (76),Sydney Cricket Ground ,26,221
# Friday,14 July,7:50 pm,Melbourne ,16.9 (105),def.,Brisbane Lions ,16.8 (104),Melbourne Cricket Ground ,38,030
# Saturday,15 July,1:45 pm,Collingwood ,18.5 (113),def.,Fremantle ,10.7 (67),Melbourne Cricket Ground ,61,157
# Saturday,15 July,2:10 pm,Gold Coast ,11.11 (77),def.,St Kilda ,8.3 (51),Heritage Bank Stadium ,13,015
# Saturday,15 July,4:35 pm,Carlton ,18.14 (122),def.,Port Adelaide ,10.12 (72),Marvel Stadium ,34,306
# Saturday,15 July,7:25 pm,Geelong ,18.14 (122),def.,Essendon ,7.3 (45),GMHBA Stadium ,23,185
# Saturday,15 July,7:10 pm,Adelaide ,8.9 (57),def. by,Greater Western Sydney ,10.11 (71),Adelaide Oval ,36,674
# Sunday,16 July,1:10 pm,North Melbourne ,6.4 (40),def. by,Hawthorn ,12.16 (88),Marvel Stadium ,30,201
# Sunday,16 July,2:40 pm,West Coast ,8.12 (60),def. by,Richmond ,14.14 (98),Optus Stadium ,40,501
# Round 19
# Friday,21 July,7:50 pm,Essendon ,7.7 (49),def. by,Western Bulldogs ,13.12 (90),Marvel Stadium ,43,634
# Saturday,22 July,1:45 pm,Richmond ,14.12 (96),def.,Hawthorn ,15.5 (95),Melbourne Cricket Ground ,57,654
# Saturday,22 July,2:10 pm,Carlton ,21.14 (140),def.,West Coast ,10.9 (69),Marvel Stadium ,34,954
# Saturday,22 July,4:35 pm,Brisbane Lions ,9.10 (64),def.,Geelong ,7.11 (53),The Gabba ,32,586
# Saturday,22 July,5:40 pm,Fremantle ,12.4 (76),def. by,Sydney ,16.9 (105),Optus Stadium ,42,433
# Saturday,22 July,7:10 pm,Port Adelaide ,12.11 (83),def. by,Collingwood ,13.7 (85),Adelaide Oval ,47,965
# Sunday,23 July,1:10 pm,Greater Western Sydney ,15.13 (103),def.,Gold Coast ,9.9 (63),Manuka Oval ,10,026
# Sunday,23 July,3:20 pm,Melbourne ,14.13 (97),def.,Adelaide ,13.15 (93),Melbourne Cricket Ground ,33,122
# Sunday,23 July,4:40 pm,St Kilda ,9.15 (69),def.,North Melbourne ,9.7 (61),Marvel Stadium ,18,279
# Round 20
# Friday,28 July,7:50 pm,Collingwood ,10.16 (76),def. by,Carlton ,14.9 (93),Melbourne Cricket Ground ,86,785
# Saturday,29 July,1:45 pm,Geelong ,9.10 (64),def. by,Fremantle ,10.11 (71),GMHBA Stadium ,21,619
# Saturday,29 July,1:45 pm,Western Bulldogs ,10.13 (73),def. by,Greater Western Sydney ,11.12 (78),Mars Stadium ,9,080
# Saturday,29 July,4:35 pm,Gold Coast ,15.6 (96),def.,Brisbane Lions ,7.13 (55),Heritage Bank Stadium ,14,097
# Saturday,29 July,7:25 pm,Essendon ,15.9 (99),def. by,Sydney ,15.11 (101),Marvel Stadium ,38,329
# Saturday,29 July,7:10 pm,Adelaide ,16.16 (112),def.,Port Adelaide ,9.11 (65),Adelaide Oval ,50,023
# Sunday,30 July,1:10 pm,Hawthorn ,14.9 (93),def. by,St Kilda ,19.8 (122),Marvel Stadium ,22,769
# Sunday,30 July,3:20 pm,Richmond ,15.8 (98),def. by,Melbourne ,20.10 (130),Melbourne Cricket Ground ,52,294
# Sunday,30 July,4:40 pm,West Coast ,10.12 (72),def.,North Melbourne ,10.7 (67),Optus Stadium ,38,231
# Round 21
# Friday,4 August,7:50 pm,Western Bulldogs ,19.12 (126),def.,Richmond ,10.11 (71),Marvel Stadium ,39,304
# Saturday,5 August,1:45 pm,Essendon ,10.13 (73),def.,West Coast ,11.6 (72),Marvel Stadium ,30,742
# Saturday,5 August,1:40 pm,Adelaide ,13.11 (89),def.,Gold Coast ,9.7 (61),Adelaide Oval ,35,777
# Saturday,5 August,4:35 pm,Hawthorn ,16.9 (105),def.,Collingwood ,11.7 (73),Melbourne Cricket Ground ,62,134
# Saturday,5 August,7:25 pm,Geelong ,14.13 (97),def.,Port Adelaide ,12.13 (85),GMHBA Stadium ,21,279
# Saturday,5 August,7:30 pm,Greater Western Sydney ,12.13 (85),def. by,Sydney ,15.6 (96),Giants Stadium ,19,332
# Sunday,6 August,1:10 pm,North Melbourne ,10.11 (71),def. by,Melbourne ,15.13 (103),Blundstone Arena ,8,034
# Sunday,6 August,3:20 pm,St Kilda ,8.6 (54),def. by,Carlton ,10.13 (73),Marvel Stadium ,42,656
# Sunday,6 August,2:40 pm,Fremantle ,11.8 (74),def. by,Brisbane Lions ,11.11 (77),Optus Stadium ,37,845
# Round 22
# Friday,11 August,7:50 pm,Collingwood ,16.13 (109),def.,Geelong ,15.11 (101),Melbourne Cricket Ground ,78,749
# Saturday,12 August,1:45 pm,North Melbourne ,12.5 (77),def. by,Essendon ,13.8 (86),Marvel Stadium ,37,231
# Saturday,12 August,1:45 pm,Sydney ,18.6 (114),def.,Gold Coast ,13.12 (90),Sydney Cricket Ground ,33,911
# Saturday,12 August,4:35 pm,Brisbane Lions ,15.9 (99),def.,Adelaide ,13.15 (93),The Gabba ,30,107
# Saturday,12 August,7:30 pm,Carlton ,9.6 (60),def.,Melbourne ,8.8 (56),Melbourne Cricket Ground ,68,577
# Saturday,12 August,6:10 pm,West Coast ,4.9 (33),def. by,Fremantle ,20.14 (134),Optus Stadium ,51,172
# Sunday,13 August,1:10 pm,Hawthorn ,9.13 (67),def.,Western Bulldogs ,9.10 (64),University of Tasmania ,12,480
# Sunday,13 August,3:20 pm,St Kilda ,14.9 (93),def.,Richmond ,8.9 (57),Marvel Stadium ,31,119
# Sunday,13 August,4:10 pm,Port Adelaide ,21.10 (136),def.,Greater Western Sydney ,13.7 (85),Adelaide Oval ,32,597
# 2:10 pm,4.9 (33),Round 23
# Friday,18 August,7:50 pm,Collingwood ,15.10 (100),def. by,Brisbane Lions ,19.10 (124),Marvel Stadium ,38,350
# Saturday,19 August,1:45 pm,Richmond ,14.17 (101),def.,North Melbourne ,10.12 (72),Melbourne Cricket Ground ,59,555
# Saturday,19 August,2:10 pm,Gold Coast ,13.9 (87),def. by,Carlton ,13.13 (91),Heritage Bank Stadium ,19,253
# Saturday,19 August,4:35 pm,Greater Western Sydney ,25.12 (162),def.,Essendon ,5.6 (36),Giants Stadium ,10,281
# Saturday,19 August,7:25 pm,St Kilda ,12.16 (88),def.,Geelong ,8.7 (55),Marvel Stadium ,40,103
# Saturday,19 August,7:10 pm,Adelaide ,10.13 (73),def. by,Sydney ,11.8 (74),Adelaide Oval ,44,817
# Sunday,20 August,1:10 pm,Western Bulldogs ,12.13 (85),def. by,West Coast ,14.8 (92),Marvel Stadium ,23,965
# Sunday,20 August,3:20 pm,Melbourne ,13.9 (87),def.,Hawthorn ,9.6 (60),Melbourne Cricket Ground ,50,142
# Sunday,20 August,2:40 pm,Fremantle ,8.10 (58),def. by,Port Adelaide ,11.8 (74),Optus Stadium ,38,360
# 25.12 (162),Round 24
# Friday,25 August,7:50 pm,Essendon ,3.13 (31),def. by,Collingwood ,16.5 (101),Melbourne Cricket Ground ,74,344
# Saturday,26 August,1:45 pm,North Melbourne ,20.12 (132),def.,Gold Coast ,14.13 (97),Blundstone Arena ,4,378
# Saturday,26 August,1:45 pm,Hawthorn ,8.8 (56),def. by,Fremantle ,14.9 (93),Melbourne Cricket Ground ,27,951
# Saturday,26 August,4:35 pm,Brisbane Lions ,9.18 (72),def.,St Kilda ,9.6 (60),The Gabba ,31,689
# Saturday,26 August,7:25 pm,Geelong ,11.13 (79),def. by,Western Bulldogs ,16.8 (104),GMHBA Stadium ,20,533
# Saturday,26 August,6:10 pm,West Coast ,12.6 (78),def. by,Adelaide ,17.21 (123),Optus Stadium ,47,027
# Sunday,27 August,12:00 pm,Port Adelaide ,13.16 (94),def.,Richmond ,8.15 (63),Adelaide Oval ,39,860
# Sunday,27 August,3:20 pm,Sydney ,7.14 (56),def. by,Melbourne ,11.11 (77),Sydney Cricket Ground ,41,753
# Sunday,27 August,6:10 pm,Carlton ,11.7 (73),def. by,Greater Western Sydney ,16.9 (105),Marvel Stadium ,44,354
# Connection successful
# Round 1
# Friday,1 September,7:20 pm,Melbourne ,10.13 (73),def.,Collingwood ,4.7 (31),Ikon Park ,8,412
# Saturday,2 September,1:05 pm,Carlton ,5.4 (34),def.,Gold Coast ,4.8 (32),Ikon Park ,3,244
# Saturday,2 September,2:35 pm,Adelaide ,8.10 (58),def.,Port Adelaide ,4.4 (28),Norwood Oval ,8,722
# Saturday,2 September,5:05 pm,Geelong ,10.5 (65),def.,Western Bulldogs ,2.5 (17),GMHBA Stadium ,4,404
# Saturday,2 September,7:15 pm,Hawthorn ,4.6 (30),def. by,Essendon ,7.7 (49),Kinetic Stadium ,3,722
# Sunday,3 September,1:05 pm,North Melbourne ,8.8 (56),def.,St Kilda ,2.4 (16),Blundstone Arena ,2,454
# Sunday,3 September,3:05 pm,Brisbane ,5.4 (34),def. by,Richmond ,6.4 (40),Brighton Homes Arena ,3,153
# Sunday,3 September,3:05 pm,Sydney ,7.9 (51),def.,Greater Western Sydney ,7.4 (46),North Sydney Oval ,5,474
# Sunday,3 September,3:05 pm,Fremantle ,4.3 (27),def.,West Coast ,2.7 (19),Fremantle Community Bank ,3,790
# Round 2
# Friday,8 September,5:05 pm,Richmond ,2.0 (12),def. by,Adelaide ,6.5 (41),Ikon Park ,1,083
# Saturday,9 September,11:05 am,Gold Coast ,15.9 (99),def.,West Coast ,4.2 (26),Heritage Bank Stadium ,1,071
# Saturday,9 September,12:35 pm,Port Adelaide ,4.2 (26),def. by,Brisbane ,11.10 (76),Alberton Oval ,1,928
# Saturday,9 September,1:05 pm,Sydney ,5.11 (41),def. by,Geelong ,10.8 (68),North Sydney Oval ,2,878
# Sunday,10 September,1:05 pm,Western Bulldogs ,5.9 (39),def. by,Hawthorn ,6.10 (46),Mars Stadium ,1,564
# Sunday,10 September,1:05 pm,Collingwood ,7.4 (46),def.,Fremantle ,3.7 (25),Victoria Park ,1,914
# Sunday,10 September,3:05 pm,North Melbourne ,10.6 (66),def.,Carlton ,1.0 (6),Arden Street Oval ,2,788
# Sunday,10 September,3:05 pm,Essendon ,6.4 (40),def.,St Kilda ,4.4 (28),Windy Hill ,3,195
# Sunday,10 September,5:05 pm,Greater Western Sydney ,3.4 (22),def. by,Melbourne ,15.9 (99),Manuka Oval ,2,028
# 15.9 (99),Round 3
# Friday,15 September,5:05 pm,Geelong ,3.4 (22),def. by,North Melbourne ,4.7 (31),GMHBA Stadium ,2,907
# Saturday,16 September,1:35 pm,Greater Western Sydney ,5.4 (34),def. by,Richmond ,7.11 (53),Blacktown ISP Oval ,1,051
# Saturday,16 September,2:35 pm,Adelaide ,12.9 (81),def.,Essendon ,5.4 (34),Unley Oval ,2,238
# Saturday,16 September,3:05 pm,Melbourne ,12.11 (83),def.,Western Bulldogs ,6.5 (41),Casey Fields ,1,457
# Saturday,16 September,3:05 pm,Fremantle ,5.5 (35),def.,Hawthorn ,3.4 (22),Fremantle Community Bank ,2,092
# Sunday,17 September,1:05 pm,St Kilda ,7.6 (48),def. by,Port Adelaide ,8.8 (56),RSEA Park ,2,016
# Sunday,17 September,1:05 pm,West Coast ,3.6 (24),def. by,Carlton ,12.5 (77),Mineral Resources Park ,1,208
# Sunday,17 September,3:05 pm,Collingwood ,2.9 (21),def. by,Gold Coast ,5.3 (33),Victoria Park ,2,537
# Sunday,17 September,5:05 pm,Brisbane ,14.3 (87),def.,Sydney ,4.8 (32),Brighton Homes Arena ,2,582
# Round 4
# Friday,22 September,5:05 pm,Hawthorn ,1.5 (11),def. by,Melbourne ,10.10 (70),Kinetic Stadium ,2,817
# Saturday,23 September,11:05 am,Greater Western Sydney ,5.7 (37),def. by,Adelaide ,16.10 (106),Manuka Oval ,1,809
# Saturday,23 September,1:05 pm,Carlton ,6.4 (40),def. by,Richmond ,7.5 (47),Ikon Park ,2,304
# Saturday,23 September,12:35 pm,Port Adelaide ,5.12 (42),def. by,Geelong ,11.4 (70),Alberton Oval ,2,132
# Sunday,24 September,1:05 pm,Sydney ,5.4 (34),def.,West Coast ,2.9 (21),Henson Park ,4,595
# Sunday,24 September,1:05 pm,North Melbourne ,5.3 (33),def. by,Brisbane ,5.5 (35),University of Tasmania ,1,093
# Sunday,24 September,3:05 pm,Essendon ,7.8 (50),def.,Fremantle ,4.6 (30),Windy Hill ,2,822
# Sunday,24 September,3:05 pm,St Kilda ,7.5 (47),def.,Collingwood ,5.5 (35),RSEA Park ,3,230
# Sunday,24 September,5:05 pm,Gold Coast ,7.6 (48),def.,Western Bulldogs ,7.2 (44),Heritage Bank Stadium ,1,181
# 16.10 (106),Round 5
# Thursday,28 September,6:15 pm,Geelong ,4.1 (25),def. by,Melbourne ,11.8 (74),GMHBA Stadium ,4,312
# Friday,29 September,1:05 pm,Richmond ,4.6 (30),def. by,Fremantle ,5.7 (37),Ikon Park ,2,406
# Friday,29 September,4:05 pm,Carlton ,6.8 (44),def.,Sydney ,6.3 (39),Ikon Park ,2,079
# Friday,29 September,7:15 pm,Western Bulldogs ,6.0 (36),def. by,St Kilda ,8.6 (54),Whitten Oval ,2,807
# Friday,29 September,7:15 pm,West Coast ,6.3 (39),def.,Port Adelaide ,4.9 (33),Mineral Resources Park ,1,134
# Saturday,30 September,11:05 am,Collingwood ,6.8 (44),def.,Essendon ,3.6 (24),Punt Road Oval ,1,422
# Sunday,1 October,1:05 pm,North Melbourne ,4.8 (32),def.,Greater Western Sydney ,0.2 (2),Arden Street Oval ,1,833
# Sunday,1 October,3:05 pm,Hawthorn ,5.2 (32),def. by,Brisbane ,8.11 (59),Kinetic Stadium ,1,755
# Sunday,1 October,4:35 pm,Adelaide ,7.5 (47),def.,Gold Coast ,2.3 (15),Unley Oval ,3,300
# Round 6
# Friday,6 October,7:15 pm,Western Bulldogs ,4.10 (34),def. by,Carlton ,8.5 (53),Whitten Oval ,2,163
# Saturday,7 October,1:05 pm,Greater Western Sydney ,6.8 (44),def.,West Coast ,3.6 (24),Blacktown ISP Oval ,Saturday,7 October,3:05 pm,Melbourne ,7.4 (46),def. by,Adelaide ,8.8 (56),Casey Fields ,1,975
# Saturday,7 October,3:05 pm,St Kilda ,7.3 (45),def.,Hawthorn ,5.6 (36),RSEA Park ,2,812
# Saturday,7 October,4:35 pm,Port Adelaide ,3.12 (30),def. by,Sydney ,6.9 (45),Alberton Oval ,2,597
# Saturday,7 October,6:15 pm,Brisbane ,3.10 (28),def. by,Collingwood ,5.3 (33),Brighton Homes Arena ,3,276
# Sunday,8 October,1:05 pm,Essendon ,4.5 (29),def.,Geelong ,2.7 (19),2,832
# Sunday,8 October,3:05 pm,Richmond ,5.5 (35),def. by,Gold Coast ,5.6 (36),Ikon Park ,1,848
# Sunday,8 October,2:05 pm,Fremantle ,3.3 (21),def. by,North Melbourne ,10.6 (66),Fremantle Community Bank ,2,022
# Round 7
# Friday,13 October,6:45 pm,Adelaide ,9.5 (59),def.,Western Bulldogs ,2.5 (17),Norwood Oval ,2,745
# Saturday,14 October,1:05 pm,St Kilda ,7.6 (48),def.,Greater Western Sydney ,5.5 (35),RSEA Park ,1,402
# Saturday,14 October,3:05 pm,Geelong ,6.11 (47),def.,Walyalup ,3.5 (23),GMHBA Stadium ,2,166
# Saturday,14 October,3:05 pm,Sydney ,3.8 (26),def. by,Hawthorn ,5.10 (40),Henson Park ,4,514
# Saturday,14 October,4:05 pm,Gold Coast ,3.3 (21),def. by,Brisbane ,8.9 (57),Heritage Bank Stadium ,1,873
# Saturday,14 October,7:20 pm,Richmond ,5.6 (36),def. by,Essendon ,8.5 (53),Ikon Park ,2,847
# Sunday,15 October,1:05 pm,North Melbourne ,13.9 (87),def.,Yartapuulti ,3.6 (24),Arden Street Oval ,1,912
# Sunday,15 October,3:05 pm,Carlton ,1.4 (10),def. by,Collingwood ,4.3 (27),Ikon Park ,3,111
# Sunday,15 October,2:05 pm,West Coast ,2.0 (12),def. by,Narrm ,11.16 (82),Mineral Resources Park ,1,232
# 13.9 (87),Round 8
# Friday,20 October,6:45 pm,Hawthorn ,4.6 (30),def. by,Richmond ,6.5 (41),Cazalys Stadium ,1,933
# Saturday,21 October,1:05 pm,Western Bulldogs ,6.3 (39),def. by,Sydney ,14.12 (96),Whitten Oval ,2,982
# Saturday,21 October,2:05 pm,Brisbane ,5.12 (42),def.,Adelaide ,6.3 (39),Brighton Homes Arena ,2,544
# Saturday,21 October,3:05 pm,Greater Western Sydney ,8.1 (49),def.,Carlton ,7.5 (47),Henson Park ,1,574
# Saturday,21 October,4:35 pm,Yartapuulti ,7.3 (45),drew with,Gold Coast ,7.3 (45),Alberton Oval ,1,853
# Saturday,21 October,7:15 pm,Narrm ,5.7 (37),def.,North Melbourne ,2.2 (14),Ikon Park ,2,704
# Sunday,22 October,1:05 pm,Collingwood ,4.6 (30),def.,Geelong ,3.6 (24),Victoria Park ,2,527
# Sunday,22 October,12:05 pm,Walyalup ,6.9 (45),def.,St Kilda ,3.3 (21),Fremantle Community Bank ,1,850
# Sunday,22 October,5:05 pm,Essendon ,2.7 (19),def. by,West Coast ,3.5 (23),Windy Hill ,2,108
# 14.12 (96),Round 9
# Friday,27 October,6:45 pm,Gold Coast ,7.6 (48),def.,Greater Western Sydney ,2.5 (17),Heritage Bank Stadium ,1,045
# Saturday,28 October,1:05 pm,Melbourne ,8.13 (61),def.,Fremantle ,4.4 (28),Casey Fields ,1,650
# Saturday,28 October,3:05 pm,St Kilda ,8.7 (55),def.,Brisbane ,5.4 (34),RSEA Park ,2,005
# Saturday,28 October,3:05 pm,Essendon ,8.8 (56),def.,Carlton ,3.6 (24),Windy Hill ,3,812
# Saturday,28 October,2:05 pm,West Coast ,5.6 (36),def. by,Western Bulldogs ,6.8 (44),Mineral Resources Park ,1,447
# Saturday,28 October,7:15 pm,Richmond ,1.5 (11),def. by,Geelong ,6.13 (49),Ikon Park ,2,021
# Sunday,29 October,1:05 pm,Sydney ,9.4 (58),def.,Collingwood ,5.9 (39),Henson Park ,5,722
# Sunday,29 October,2:35 pm,Adelaide ,6.5 (41),def.,North Melbourne ,5.8 (38),Norwood Oval ,3,362
# Sunday,29 October,5:05 pm,Hawthorn ,6.4 (40),def.,Port Adelaide ,5.2 (32),Kinetic Stadium ,1,771
# Round 10
# Friday,3 November,6:45 pm,Gold Coast ,6.3 (39),def.,Essendon ,3.7 (25),Great Barrier Reef ,2,131
# Saturday,4 November,1:05 pm,Western Bulldogs ,1.3 (9),def. by,North Melbourne ,7.13 (55),Whitten Oval ,2,608
# Saturday,4 November,2:35 pm,Port Adelaide ,13.10 (88),def.,Greater Western Sydney ,4.6 (30),Alberton Oval ,3,353
# Saturday,4 November,5:05 pm,Geelong ,9.6 (60),def.,Hawthorn ,3.2 (20),GMHBA Stadium ,3,658
# Saturday,4 November,2:05 pm,West Coast ,6.9 (45),def. by,Adelaide ,11.5 (71),Mineral Resources Park ,Saturday,4 November,6:05 pm,Brisbane ,8.5 (53),def.,Melbourne ,4.4 (28),Brighton Homes Arena ,3,004
# Sunday,5 November,1:05 pm,Carlton ,3.8 (26),def. by,St Kilda ,7.4 (46),Ikon Park ,2,649
# Sunday,5 November,3:05 pm,Collingwood ,4.1 (25),def. by,Richmond ,11.11 (77),Victoria Park ,3,948
# Sunday,5 November,2:05 pm,Fremantle ,2.6 (18),def. by,Sydney ,5.10 (40),Fremantle Community Bank ,2,271
# 13.10 (88),
